# %% [markdown]
# <a href="https://colab.research.google.com/github/Aswin-1121/ICT-DSA/blob/main/Virtual_competition_12_3_24.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# importing libraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# Consider the following Python dictionary `data` and Python list `labels`:
#
# ``` python
# data = {'animal': ['cat', 'cat', 'snake', 'dog', 'dog', 'cat', 'snake', 'cat', 'dog', 'dog'],
#         'age': [2.5, 3, 0.5, np.nan, 5, 2, 4.5, np.nan, 7, 3],
#         'visits': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
#         'priority': ['yes', 'yes', 'no', 'yes', 'no', 'no', 'no', 'yes', 'no', 'no']}
#
# labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']
# ```
#
# **1.** Create a DataFrame `df` from this dictionary `data` which has the index `labels`.

# %%
data = {'animal': ['cat', 'cat', 'snake', 'dog', 'dog', 'cat', 'snake', 'cat', 'dog', 'dog'],
        'age': [2.5, 3, 0.5, np.nan, 5, 2, 4.5, np.nan, 7, 3],
        'visits': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
        'priority': ['yes', 'yes', 'no', 'yes', 'no', 'no', 'no', 'yes', 'no', 'no']}

labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']
df = pd.DataFrame(data, index=labels)
df
# Out:
#   animal  age  visits priority
# a    cat  2.5       1      yes
# b    cat  3.0       3      yes
# c  snake  0.5       2       no
# d    dog  NaN       3      yes
# e    dog  5.0       2       no
# f    cat  2.0       3       no
# g  snake  4.5       1       no
# h    cat  NaN       1      yes
# i    dog  7.0       2       no
# j    dog  3.0       1       no

# %% [markdown]
# **2.** Display a summary of the basic information about this DataFrame and its data (*hint: there is a single method that can be called on the DataFrame*).

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10 entries, a to j
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   animal    10 non-null     object
#  1   age       8 non-null      float64
#  2   visits    10 non-null     int64
#  3   priority  10 non-null     object
# dtypes: float64(1), int64(1), object(2)
# memory usage: 700.0+ bytes

# %% [markdown]
# **3.** Return the first 3 rows of the DataFrame `df`.

# %%
df.head(3)
# Out:
#   animal  age  visits priority
# a    cat  2.5       1      yes
# b    cat  3.0       3      yes
# c  snake  0.5       2       no

# %% [markdown]
# **4.** Display the 'animal' and 'age' columns from the DataFrame `df`

# %%
df[['animal','age']]
# Out:
#   animal  age
# a    cat  2.5
# b    cat  3.0
# c  snake  0.5
# d    dog  NaN
# e    dog  5.0
# f    cat  2.0
# g  snake  4.5
# h    cat  NaN
# i    dog  7.0
# j    dog  3.0

# %% [markdown]
# **5.** Display the data in rows `[3, 4, 8]` *and* in columns `['animal', 'age']'

# %%
asd = df.loc[df.index[[3, 4, 8]], ['animal', 'age']]
asd
# Out:
#   animal  age
# d    dog  NaN
# e    dog  5.0
# i    dog  7.0

# %% [markdown]
# **6.** Select only the rows where the number of visits is greater than 3.

# %%
visit = df[df['visits']>3]
visit
# Out:
# Empty DataFrame
# Columns: [animal, age, visits, priority]
# Index: []

# %% [markdown]
# **7.** Select the rows where the age is missing, i.e. it is `NaN`.

# %%
age_miss = df[df['age'].isna()]
age_miss
# Out:
#   animal  age  visits priority
# d    dog  NaN       3      yes
# h    cat  NaN       1      yes

# %% [markdown]
# **8.** Select the rows where the animal is a cat *and* the age is less than 3.

# %%
cat_age = df[(df['animal']== 'cat') & (df['age']== 3)]
cat_age
# Out:
#   animal  age  visits priority
# b    cat  3.0       3      yes

# %% [markdown]
# **9.** Select the rows where the age is between 2 and 4 (inclusive)

# %%
age = df[(df['age']>=2)& (df['age']<=4)]
age
# Out:
#   animal  age  visits priority
# a    cat  2.5       1      yes
# b    cat  3.0       3      yes
# f    cat  2.0       3       no
# j    dog  3.0       1       no

# %% [markdown]
# **10.** Change the age in row 'f' to 1.5.

# %%
df.loc['f','age']=1.5
df
# Out:
#   animal  age  visits priority
# a    cat  2.5       1      yes
# b    cat  3.0       3      yes
# c  snake  0.5       2       no
# d    dog  NaN       3      yes
# e    dog  5.0       2       no
# f    cat  1.5       3       no
# g  snake  4.5       1       no
# h    cat  NaN       1      yes
# i    dog  7.0       2       no
# j    dog  3.0       1       no

# %% [markdown]
# **11.** Calculate the sum of all visits in `df` (i.e. the total number of visits).

# %%
sum_visits = df['visits'].sum()
sum_visits
# Out:
# 19

# %% [markdown]
# **12.** Calculate the mean age for each different animal in `df`.

# %%
mean_aa = df.groupby('animal')['age'].mean()
mean_aa
# Out:
# animal
# cat      2.333333
# dog      5.000000
# snake    2.500000
# Name: age, dtype: float64

# %% [markdown]
# **13.** Append a new row 'k' to `df` with your choice of values for each column. Then delete that row to return the original DataFrame.

# %%
df.loc['k'] = ['lion',15,5,'yes']
df
# Out:
#   animal   age  visits priority
# a    cat   2.5       1      yes
# b    cat   3.0       3      yes
# c  snake   0.5       2       no
# d    dog   NaN       3      yes
# e    dog   5.0       2       no
# f    cat   1.5       3       no
# g  snake   4.5       1       no
# h    cat   NaN       1      yes
# i    dog   7.0       2       no
# j    dog   3.0       1       no
# k   lion  15.0       5      yes

# %%
df=df.drop('k')
df
# Out:
#   animal  age  visits priority
# a    cat  2.5       1      yes
# b    cat  3.0       3      yes
# c  snake  0.5       2       no
# d    dog  NaN       3      yes
# e    dog  5.0       2       no
# f    cat  1.5       3       no
# g  snake  4.5       1       no
# h    cat  NaN       1      yes
# i    dog  7.0       2       no

# %% [markdown]
# **14.** Count the number of each type of animal in `df`.

# %%
cnt = df['animal'].value_counts()
cnt
# Out:
# cat      4
# dog      3
# snake    2
# Name: animal, dtype: int64

# %% [markdown]
# **15.** Sort `df` first by the values in the 'age' in *descending* order, then by the value in the 'visits' column in *ascending* order (so row `i` should be first, and row `d` should be last).

# %%
df
# Out:
#   animal  age  visits priority
# a    cat  2.5       1      yes
# b    cat  3.0       3      yes
# c  snake  0.5       2       no
# d    dog  NaN       3      yes
# e    dog  5.0       2       no
# f    cat  1.5       3       no
# g  snake  4.5       1       no
# h    cat  NaN       1      yes
# i    dog  7.0       2       no

# %%
sort_df = df.sort_values(by=['age', 'visits'], ascending=[False, True])
sort_df
# Out:
#   animal  age  visits priority
# i    dog  7.0       2       no
# e    dog  5.0       2       no
# g  snake  4.5       1       no
# b    cat  3.0       3      yes
# a    cat  2.5       1      yes
# f    cat  1.5       3       no
# c  snake  0.5       2       no
# h    cat  NaN       1      yes
# d    dog  NaN       3      yes

# %% [markdown]
# **16.** The 'priority' column contains the values 'yes' and 'no'. Replace this column with a column of boolean values: 'yes' should be `True` and 'no' should be `False`.

# %%
df['priority'] = df['priority'].replace({'yes': True, 'no': False})
df
# Out:
#   animal  age  visits  priority
# a    cat  2.5       1      True
# b    cat  3.0       3      True
# c  snake  0.5       2     False
# d    dog  NaN       3      True
# e    dog  5.0       2     False
# f    cat  1.5       3     False
# g  snake  4.5       1     False
# h    cat  NaN       1      True
# i    dog  7.0       2     False

# %% [markdown]
# **17.** In the 'animal' column, change the 'snake' entries to 'python'.

# %%
df['animal'] = df['animal'].replace('snake', 'python')
df
# Out:
#    animal  age  visits  priority
# a     cat  2.5       1      True
# b     cat  3.0       3      True
# c  python  0.5       2     False
# d     dog  NaN       3      True
# e     dog  5.0       2     False
# f     cat  1.5       3     False
# g  python  4.5       1     False
# h     cat  NaN       1      True
# i     dog  7.0       2     False

# %% [markdown]
# **18.** Load the ny-flights dataset to Python

# %%
ny =pd.read_csv('/content/ny-flights (2).csv')
ny
# Out:
#                    fl_date unique_carrier  airline_id tail_num  fl_num origin  \
# 0      2014-01-01 00:00:00             AA       19805   N338AA       1    JFK
# 1      2014-01-01 00:00:00             AA       19805   N335AA       3    JFK
# 2      2014-01-01 00:00:00             AA       19805   N327AA      21    JFK
# 3      2014-01-01 00:00:00             AA       19805   N3EHAA      29    LGA
# 4      2014-01-01 00:00:00             AA       19805   N319AA     117    JFK
# ...                    ...            ...         ...      ...     ...    ...
# 20812  2014-01-31 00:00:00             UA       19977   N54711    1253    ROC
# 20813  2014-01-31 00:00:00             UA       19977   N77525    1429    LGA
# 20814  2014-01-31 00:00:00             UA       19977   N37293    1456    LGA
# 20815  2014-01-31 00:00:00             UA       19977   N24729    1457    LGA
# 20816  2014-01-31 00:00:00             MQ       20398   N609MQ    3699    BUF
#
# ...

# %%
ny.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20817 entries, 0 to 20816
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   fl_date         20817 non-null  object
#  1   unique_carrier  20817 non-null  object
#  2   airline_id      20817 non-null  int64
#  3   tail_num        20512 non-null  object
#  4   fl_num          20817 non-null  int64
#  5   origin          20817 non-null  object
#  6   dest            20817 non-null  object
#  7   dep_time        18462 non-null  float64
#  8   dep_delay       18462 non-null  float64
#  9   arr_time        18412 non-null  float64
#  10  arr_delay       18383 non-null  float64
#  11  cancelled       20817 non-null  float64
#  12  arr             18412 non-null  object
#  13  dep             18462 non-null  object
# dtypes: float64(5), int64(2), object(7)
# memory usage: 2.2+ MB

# %%
ny.shape
# Out:
# (20817, 14)

# %%
ny.describe()
# Out:
#          airline_id        fl_num      dep_time     dep_delay      arr_time  \
# count  20817.000000  20817.000000  18462.000000  18462.000000  18412.000000
# mean   20109.614882   1826.098813   1319.991713     22.772127   1493.698566
# std      370.715209   1548.188325    479.999940     59.766152    518.851657
# min    19393.000000      1.000000      1.000000   -112.000000      1.000000
# 25%    19790.000000    472.000000    858.000000     -4.000000   1110.750000
# 50%    20355.000000   1457.000000   1336.000000      0.000000   1519.000000
# 75%    20409.000000   2701.000000   1720.000000     22.000000   1923.000000
# max    21171.000000   6258.000000   2400.000000    973.000000   2400.000000
#
#           arr_delay    cancelled
# count  18383.000000  20817.00000
# mean      21.380732      0.11505
# std       64.605591      0.31909
# min     -112.000000      0.00000
# 25%      -12.000000      0.00000
# 50%        3.000000      0.00000
# 75%       28.000000      0.00000
# ...

# %%
ny.columns
# Out:
# Index(['fl_date', 'unique_carrier', 'airline_id', 'tail_num', 'fl_num',
#        'origin', 'dest', 'dep_time', 'dep_delay', 'arr_time', 'arr_delay',
#        'cancelled', 'arr', 'dep'],
#       dtype='object')

# %% [markdown]
# **19.** Which airline ID is present maximum times in the dataset

# %%
max_id = ny['airline_id'].value_counts().idxmax()
max_id
# Out:
# 20409

# %% [markdown]
# **20.** Draw a plot between dep_delay and arr_delay

# %%
dn =ny.head()
dn
# Out:
#                fl_date unique_carrier  airline_id tail_num  fl_num origin  \
# 0  2014-01-01 00:00:00             AA       19805   N338AA       1    JFK
# 1  2014-01-01 00:00:00             AA       19805   N335AA       3    JFK
# 2  2014-01-01 00:00:00             AA       19805   N327AA      21    JFK
# 3  2014-01-01 00:00:00             AA       19805   N3EHAA      29    LGA
# 4  2014-01-01 00:00:00             AA       19805   N319AA     117    JFK
#
#   dest  dep_time  dep_delay  arr_time  arr_delay  cancelled  \
# 0  LAX     914.0       14.0    1238.0       13.0        0.0
# 1  LAX    1157.0       -3.0    1523.0       13.0        0.0
# 2  LAX    1902.0        2.0    2224.0        9.0        0.0
# 3  PBI     722.0       -8.0    1014.0      -26.0        0.0
# 4  LAX    1347.0        2.0    1706.0        1.0        0.0
#
#                    arr                  dep
# 0  2014-01-01 12:38:00  2014-01-01 09:14:00
# 1  2014-01-01 15:23:00  2014-01-01 11:57:00
# ...

# %%
sns.lineplot(data=ny, x="dep_delay", y="arr_delay",hue='airline_id')
# Out:
# <Axes: xlabel='dep_delay', ylabel='arr_delay'>

# %%
sns.lineplot(data=dn, x="dep_delay", y="arr_delay",hue='airline_id')
# Out:
# <Axes: xlabel='dep_delay', ylabel='arr_delay'>
